# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
url = "https://indeed11.p.rapidapi.com/"

payload = {
	"search_terms": "Data Analyst",
	"location": "",
	"page": "1",
	"fetch_full_text": "yes"
}
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Host": "indeed11.p.rapidapi.com",
	"X-RapidAPI-Key": "546b20b9e6msh4ea959bb495cf70p109c4djsnde57e446b2f3"
}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)
# Out:
# [{"date": "3 days ago", "job_title": "Data and Business Intelligence Analyst - Remote", "company_name": "Psychology Today", "location": "Remote", "salary": "$125,000 - $150,000 a year", "url": "https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0D-whM9RQVq1qW3DH_z0stm10FDmxqqy6U9I-zcPBa4uUICpohdhyXKKwUTXrf8xj3AO8aCXJQL1qztgjw-Xg1gmLecHNarxe7KgFvAmI0ATW0atovodorllaxu5_qshB_9jlIVPQB3w8rtjYjLW-HU7nmOpRw2InzpL_yrnIKWai67K8bITBh0K3wiWhNyX08giTg-TCNHy4Mf7IjeOt9plfNp4MvQSF6rknyPUoaqYBYDF5AFXZb0cJ9fFQ4eg4L4lokc2Vfx7KU4us-074vy9hwT4yVKNL7m7a_ptLhc6unfu450nGkJKyvU94ET9Q_GLOcvkF2mbRfHqPeHZ_4mRG7wMMZaLv5hzvZOMa_4oc15gxycOZTh6A_AWwRUOPV7qYPqLkD5Jnxa6jHnyBWM7zzHjfoHJovGenXI5lw8wEpavMkhrHFQv5E8o0RBscw=&p=0&fvj=1&vjs=3", "summary": "Develop ad-hoc analyses for BI and data teams.\nCommunicate and present data to stakeholders in a way that highlights important KPI's.", "full_text": "\nAbout us: \nWe are Psychology Today \u2013 the world's #1 psychology site visited by over 40 million people a month. W
# ...

# %%
jobs_ind = json.loads(response.content)
json.dumps(jobs_ind, indent=3)
# Out:
# '[\n   {\n      "date": "3 days ago",\n      "job_title": "Data and Business Intelligence Analyst - Remote",\n      "company_name": "Psychology Today",\n      "location": "Remote",\n      "salary": "$125,000 - $150,000 a year",\n      "url": "https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0D-whM9RQVq1qW3DH_z0stm10FDmxqqy6U9I-zcPBa4uUICpohdhyXKKwUTXrf8xj3AO8aCXJQL1qztgjw-Xg1gmLecHNarxe7KgFvAmI0ATW0atovodorllaxu5_qshB_9jlIVPQB3w8rtjYjLW-HU7nmOpRw2InzpL_yrnIKWai67K8bITBh0K3wiWhNyX08giTg-TCNHy4Mf7IjeOt9plfNp4MvQSF6rknyPUoaqYBYDF5AFXZb0cJ9fFQ4eg4L4lokc2Vfx7KU4us-074vy9hwT4yVKNL7m7a_ptLhc6unfu450nGkJKyvU94ET9Q_GLOcvkF2mbRfHqPeHZ_4mRG7wMMZaLv5hzvZOMa_4oc15gxycOZTh6A_AWwRUOPV7qYPqLkD5Jnxa6jHnyBWM7zzHjfoHJovGenXI5lw8wEpavMkhrHFQv5E8o0RBscw=&p=0&fvj=1&vjs=3",\n      "summary": "Develop ad-hoc analyses for BI and data teams.\\nCommunicate and present data to stakeholders in a way that highlights important KPI\'s.",\n      "full_text": "\\nAbout us: \\nWe are Psychology Today \\u2013 the wor
# ...

# %%
jobs_indeed = pd.json_normalize(jobs_ind, sep="_")

# %%
jobs_indeed.head()
# Out:
#                         date                                        job_title  \
# 0                 3 days ago  Data and Business Intelligence Analyst - Remote
# 1                 3 days ago        Strategy and Data Analyst, Sustainability
# 2                      Today                                     Data Analyst
# 3                      Today                                     Data Analyst
# 4  EmployerActive 7 days ago                                     Data Analyst
#
#              company_name                                           location  \
# 0        Psychology Today                                             Remote
# 1                    Uber  San Francisco, CA 94103 (South of Market area)...
# 2              RPM Living                                   Austin, TX 78731
# 3  Amerit Fleet Solutions                                             Remote
# 4                 LinkIt!                 Manhattan, NY 10011 (Chelsea area)
#
# ...

# %%
jobs_indeed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          15 non-null     object
#  1   job_title     15 non-null     object
#  2   company_name  15 non-null     object
#  3   location      15 non-null     object
#  4   salary        15 non-null     object
#  5   url           15 non-null     object
#  6   summary       15 non-null     object
#  7   full_text     15 non-null     object
# dtypes: object(8)
# memory usage: 1.1+ KB
